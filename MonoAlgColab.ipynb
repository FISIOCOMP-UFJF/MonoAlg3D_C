# %%
# %%shell
# #Verificando GPU e instalando dependências
# nvidia-smi
# apt-get install libx11-dev libxcursor-dev libxrandr-dev libxinerama-dev libz-dev libxi-dev libglu1-mesa-dev libglvnd-dev
# Out:
# Mon Jun 19 14:32:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %%shell
# #Compilando o código. Vai dar erro no mpi, mas vai gerar o executável padrao.
# git clone https://github.com/FISIOCOMP-UFJF/MonoAlg3D_C.git
# cd MonoAlg3D_C
# ./build.sh
# Out:
# fatal: destination path 'MonoAlg3D_C' already exists and is not an empty directory.
# Linux version: Ubuntu-20.04
# C compiler: gcc
# C++ compiler: g++
# CUDA compiler: /usr/local/cuda/bin/nvcc
# CUDA libraries path: /usr/local/cuda/targets/x86_64-linux/lib
# CUDA include path: /usr/local/cuda/include/
# C FLAGS: -DCELL_MODEL_REAL_DOUBLE -O3 -fopenmp -std=gnu99 -fno-strict-aliasing  -Wall -Wno-stringop-truncation -Wno-unused-function -Wno-char-subscripts -Wno-unused-result -Wno-switch -Werror=implicit-function-declaration -DCOMPILE_CUDA -I/usr/local/cuda/include/ -DCOMPILE_GUI
# [INFO] COMPILING STATIC LIB raylib
# gcc  -c rglfw.c -Wall -D_DEFAULT_SOURCE -Wno-missing-braces -Werror=pointer-arith -fno-strict-aliasing -std=c99 -fPIC -s -O1 -Werror=implicit-function-declaration -I. -Iexternal/glfw/include -Iexternal/glfw/deps/mingw -DPLATFORM_DESKTOP -DGRAPHICS_API_OPENGL_33
# In file included from rglfw.c:97:
# external/glfw/src/posix_time.c:30: warning: "_POSIX_C_SOURCE" redefined
# ...

# %%
# %%shell
# cd MonoAlg3D_C/
# ./bin/MonoAlg3D -c ./example_configs/cable_mesh_with_tt2006.ini
# Out:
# [WARN] The gpu_id option is being moved to the [main] section. Please update your config files!
# outputs does not exist! Creating!
# outputs/TT3_cable2 does not exist! Creating!
# Log will be saved in outputs/TT3_cable2/outputlog.txt
# Command line to reproduce this simulation:
# ./bin/MonoAlg3D -c ./example_configs/cable_mesh_with_tt2006.ini
# For reproducibility purposes the configuration file was copied to file: outputs/TT3_cable2/original_configuration.ini
# ...
# No configuration provided to make simulation checkpoints! Chekpoints will not be created!
# ...
# 1 devices available, running on Device 0: Tesla T4
# Initial mesh side length: 12800.000000 µm x 12800.000000 µm x 12800.000000 µm
# Loading cuboid mesh with 10000.000000 µm x 100.000000 µm x 100.000000 µm using dx 100.000000 µm, dy 100.000000 µm, dz 100.000000 µm
# Refined 1 of 1 (36 cells)
# Refined 1 of 1 (148 cells)
# Refined 1 of 1 (596 cells)
# Refined 1 of 1 (2388 cells)
# Refined 1 of 1 (9556 cells)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%shell
# cd MonoAlg3D_C/outputs/
# cp -R TT3_cable2/ /content/drive/MyDrive/MonoAlgResults/
